# %% [markdown]
# # Inference Batch — Year-wise Mining Detection
# **Notebook:** `inference_batch.ipynb`
#
# Runs the same inference pipeline as `inference_visualizer.ipynb` but loops through
# every JP2 file year by year automatically.
#
# ### What it saves (per year, best scene selected)
# ```
# inference_output/temporal/
#   2021_overlay.png          ← satellite + red highlights
#   2021_heatmap.png          ← probability heatmap
#   2021_result.json          ← mining stats (area, patches, coverage %)
#   2022_overlay.png
#   2022_heatmap.png
#   2022_result.json
#   ... (one set per year)
#   all_years_results.csv     ← combined table for temporal analysis
# ```
#
# **Then run `temporal_analysis.ipynb`** which reads these results and makes charts.

# %% [markdown]
# ## Cell 1 — Imports

# %%
import os, glob, re, json
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
from PIL import Image

import torch
import torch.nn as nn
from torchvision import transforms, models

try:
    import rasterio
    from rasterio.transform import xy as rio_xy
    from rasterio.crs import CRS
    from rasterio.enums import Resampling
    HAS_RASTERIO = True
    print('rasterio OK')
except ImportError:
    HAS_RASTERIO = False
    print('rasterio not found — install: pip install rasterio')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device:', device)
if torch.cuda.is_available():
    print('GPU   :', torch.cuda.get_device_name(0))
# Out:
# rasterio OK
# Device: cuda
# GPU   : NVIDIA GeForce RTX 4060 Laptop GPU

# %% [markdown]
# ## Cell 2 — Config
# > **Only update `DATA_ROOT`** — everything else is auto-detected.

# %%
# ── Folder containing your year subfolders ───────────────────────────────
DATA_ROOT = r"R:\ai project image\data image big"

# ── Year folder names → year labels ──────────────────────────────────────
YEAR_MAP = {
    'big 2021' : 2021,
    '2022'     : 2022,
    '2023'     : 2023,
    '2024'     : 2024,
    '2025'     : 2025,
}

# ── Model ─────────────────────────────────────────────────────────────────
MODEL_PATH  = 'saved_models/best_model.pth'
NUM_CLASSES = 2

# ── Patch settings ────────────────────────────────────────────────────────
PATCH_SIZE  = 64      # must match training patch size
STRIDE      = 32      # 50% overlap
THRESHOLD   = 0.6     # raised from 0.5 → reduces false positives on large scenes
BATCH_SIZE  = 64

# ── Sentinel-2 native resolution ─────────────────────────────────────────
NATIVE_RES_M = 10.0   # metres per pixel at native resolution
# IMPORTANT: area is computed using the NATIVE resolution, not the downsampled one.
# load_jp2 returns the scale factor so we can correct for downsampling.
# patch area = (PATCH_SIZE * native_res / scale) ** 2 in m², converted to km²
# But simpler: count mining pixels in the mask, multiply by (native_res)^2.
# We use: area_km2 = (mining_pixels_in_mask * (NATIVE_RES_M/scale)^2) / 1e6

# ── Output ────────────────────────────────────────────────────────────────
OUTPUT_DIR  = 'inference_output/temporal'
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ── Scene selection ───────────────────────────────────────────────────────
# Use MEDIAN not max_mining — median across scenes in a year is more stable
# and not skewed by one unusually clear/cloudy acquisition.
SCENE_SELECT = 'median'  # options: 'median', 'max_mining', 'first'

MAX_DIM = 15000  # Set high to prevent downsampling and preserve CNN spatial resolution!

print(f'Data root  : {DATA_ROOT}')
print(f'Model      : {MODEL_PATH}')
print(f'Output     : {OUTPUT_DIR}')
print(f'Patch size : {PATCH_SIZE}px  Stride: {STRIDE}px  Threshold: {THRESHOLD}')
print(f'Native res : {NATIVE_RES_M}m/px')

for folder, year in sorted(YEAR_MAP.items(), key=lambda x: x[1]):
    path  = os.path.join(DATA_ROOT, folder)
    files = glob.glob(os.path.join(path, '*.jp2'))
    status = f'{len(files)} JP2 files' if files else 'NOT FOUND'
    print(f'  {year} ({folder}): {status}')
# Out:
# Data root  : R:\ai project image\data image big
# Model      : saved_models/best_model.pth
# Output     : inference_output/temporal
# Patch size : 64px  Stride: 32px  Threshold: 0.6
# Native res : 10.0m/px
#   2021 (big 2021): 6 JP2 files
#   2022 (2022): 6 JP2 files
#   2023 (2023): 6 JP2 files
#   2024 (2024): 6 JP2 files
#   2025 (2025): 5 JP2 files

# %% [markdown]
# ## Cell 3 — Load Model

# %%
def load_efficientnet_b0(model_path):
    """Load EfficientNet-B0 — matches your training setup exactly."""
    model = models.efficientnet_b0(weights=None)
    in_f  = model.classifier[1].in_features   # 1280
    model.classifier = nn.Sequential(
        nn.Dropout(0.5),
        nn.Linear(in_f, 256),
        nn.ReLU(inplace=True),
        nn.Dropout(0.4),
        nn.Linear(256, NUM_CLASSES)
    )
    state = torch.load(model_path, map_location=device)
    model.load_state_dict(state)
    model.to(device).eval()
    print(f'Model loaded: {model_path}')
    return model

model = load_efficientnet_b0(MODEL_PATH)

# Transform — resize patch to 224x224 for EfficientNet
patch_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])
print('Patch transform ready.')
# Out:
# Model loaded: saved_models/best_model.pth
# Patch transform ready.

# %% [markdown]
# ## Cell 4 — Core Functions
# (Same logic as inference_visualizer.ipynb — just packaged as reusable functions)

# %%
def load_jp2(path, max_dim=MAX_DIM):
    """Load a Sentinel-2 JP2/GeoTIFF at native resolution, return RGB uint8.
    No colour stretching — raw pixel values match training data exactly.
    """
    if HAS_RASTERIO:
        with rasterio.open(path) as src:
            h, w = src.height, src.width
            scale = min(1.0, max_dim / max(h, w))
            nh, nw = int(h * scale), int(w * scale)
            data = src.read(
                out_shape=(src.count, nh, nw),
                resampling=Resampling.bilinear
            )
            geo_transform = src.transform
            crs = src.crs
        # (bands, H, W) → (H, W, 3) — NO percentile stretch, raw uint8
        data = np.moveaxis(data[:3], 0, -1).astype(np.uint8)
        return data, geo_transform, crs, scale
    else:
        img = Image.open(path).convert('RGB')
        img.thumbnail((max_dim, max_dim))
        return np.array(img), None, None, 1.0


def _resize_for_display(arr, max_side=2000):
    """Downsample array to max_side px on longest side — for PNG output only.
    Inference and statistics are always computed at full resolution.
    """
    h, w = arr.shape[:2]
    scale = min(1.0, max_side / max(h, w))
    if scale >= 1.0:
        return arr
    nh, nw = int(h * scale), int(w * scale)
    if arr.ndim == 2:
        # prob_map float32 — scale to uint8, resize, scale back
        img = Image.fromarray((arr * 255).clip(0, 255).astype(np.uint8))
        img = img.resize((nw, nh), Image.Resampling.BILINEAR if hasattr(Image, 'Resampling') else Image.BILINEAR)
        return np.array(img).astype(np.float32) / 255.0
    else:
        img = Image.fromarray(arr)
        img = img.resize((nw, nh), Image.Resampling.BILINEAR if hasattr(Image, 'Resampling') else Image.BILINEAR)
        return np.array(img)


def run_inference(img_rgb, patch_size=PATCH_SIZE, stride=STRIDE,
                  threshold=THRESHOLD, batch_size=BATCH_SIZE):
    """
    Sliding window inference on full-resolution image. Returns:
      prob_map    : (H,W) float32 — mining probability per pixel
      mining_mask : (H,W) bool    — True where mining detected
      detections  : list of {pixel_y, pixel_x, confidence}
      n_total     : total patches scanned
    """
    H, W = img_rgb.shape[:2]
    prob_map  = np.zeros((H, W), dtype=np.float32)
    count_map = np.zeros((H, W), dtype=np.float32)
    detections = []

    positions = [(y, x)
                 for y in range(0, H - patch_size + 1, stride)
                 for x in range(0, W - patch_size + 1, stride)]

    patches_buf, pos_buf = [], []

    with torch.no_grad():
        for i, (y, x) in enumerate(positions):
            patch = img_rgb[y:y+patch_size, x:x+patch_size]
            patches_buf.append(patch_transform(Image.fromarray(patch)))
            pos_buf.append((y, x))

            flush = (len(patches_buf) == batch_size) or (i == len(positions)-1)
            if flush and patches_buf:
                batch = torch.stack(patches_buf).to(device)
                probs = torch.softmax(model(batch), dim=1)[:, 0].cpu().numpy()

                for (py, px), prob in zip(pos_buf, probs):
                    prob_map [py:py+patch_size, px:px+patch_size] += prob
                    count_map[py:py+patch_size, px:px+patch_size] += 1
                    if prob >= threshold:
                        detections.append({'pixel_y': py, 'pixel_x': px,
                                           'confidence': float(prob)})
                patches_buf, pos_buf = [], []

            if (i+1) % 1000 == 0 or i == len(positions)-1:
                pct = (i+1)/len(positions)*100
                print(f'  {pct:5.1f}%  |  {i+1:,}/{len(positions):,} patches'
                      f'  |  mining so far: {len(detections):,}')

    count_map = np.maximum(count_map, 1)
    prob_map  = prob_map / count_map
    return prob_map, prob_map >= threshold, detections, len(positions)


def make_overlay(img_rgb, mining_mask):
    """Red overlay on detected mining pixels."""
    overlay = img_rgb.copy().astype(np.float32)
    overlay[mining_mask, 0] = np.clip(overlay[mining_mask, 0]*0.4 + 255*0.6, 0, 255)
    overlay[mining_mask, 1] = np.clip(overlay[mining_mask, 1]*0.4,            0, 255)
    overlay[mining_mask, 2] = np.clip(overlay[mining_mask, 2]*0.4,            0, 255)
    return overlay.astype(np.uint8)


def save_overlay_fig(img_rgb, overlay, mining_mask, detections,
                     year, date_str, out_path):
    """Save side-by-side original vs overlay figure (downsampled for rendering)."""
    coverage = mining_mask.sum() / mining_mask.size * 100
    # Downsample for matplotlib rendering only (saves ~3 GB RAM)
    img_disp     = _resize_for_display(img_rgb,  max_side=2000)
    overlay_disp = _resize_for_display(overlay,  max_side=2000)

    fig, axes = plt.subplots(1, 2, figsize=(16, 7))
    axes[0].imshow(img_disp)
    axes[0].set_title(f'Original - {year} ({date_str})', fontsize=12)
    axes[0].axis('off')
    axes[1].imshow(overlay_disp)
    axes[1].set_title(f'Mining Detection - threshold={THRESHOLD}', fontsize=12)
    axes[1].axis('off')
    red_p  = mpatches.Patch(color='red',  alpha=0.7, label='Mining detected')
    gray_p = mpatches.Patch(color='gray', alpha=0.5, label='Non-mining')
    axes[1].legend(handles=[red_p, gray_p], loc='lower right', fontsize=10)
    axes[1].text(0.02, 0.98,
                 f'Coverage: {coverage:.1f}%\nDetections: {len(detections):,}',
                 transform=axes[1].transAxes, fontsize=10, va='top',
                 bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
    plt.suptitle(f'Illegal Mining Detection - {year}', fontsize=14)
    plt.tight_layout()
    plt.savefig(out_path, dpi=150, bbox_inches='tight')
    plt.close()
    print(f'  Saved overlay: {out_path}')


def save_heatmap_fig(img_rgb, prob_map, year, out_path):
    """Save heatmap figure (downsampled for rendering)."""
    # Downsample for matplotlib rendering only (saves ~3 GB RAM)
    img_disp  = _resize_for_display(img_rgb,  max_side=2000)
    prob_disp = _resize_for_display(prob_map, max_side=2000)

    fig, axes = plt.subplots(1, 2, figsize=(16, 7))
    axes[0].imshow(img_disp)
    axes[0].set_title('Original Image', fontsize=12)
    axes[0].axis('off')
    im = axes[1].imshow(prob_disp, cmap='RdYlGn_r', vmin=0, vmax=1)
    axes[1].set_title('Mining Confidence Heatmap', fontsize=12)
    axes[1].axis('off')
    plt.colorbar(im, ax=axes[1], fraction=0.046, pad=0.04,
                 label='Mining Probability')
    plt.suptitle(f'Confidence Heatmap - {year}', fontsize=14)
    plt.tight_layout()
    plt.savefig(out_path, dpi=150, bbox_inches='tight')
    plt.close()
    print(f'  Saved heatmap : {out_path}')

print('All functions defined.')
# Out:
# All functions defined.

# %% [markdown]
# ## Cell 5 — Run Inference Year by Year
#
# This loops through every year folder, processes every JP2, picks the best scene, and saves outputs.

# %%
yearly_results = []   # one dict per year (best scene)
all_scenes     = []   # one dict per JP2 file (all scenes)

for folder_name, year in sorted(YEAR_MAP.items(), key=lambda x: x[1]):
    folder_path = os.path.join(DATA_ROOT, folder_name)
    jp2_files   = sorted(glob.glob(os.path.join(folder_path, '*.jp2')))

    if not jp2_files:
        print(f'\n{year}: no JP2 files found in {folder_path} - skipping')
        continue

    print(f'\n{"="*60}')
    print(f'  Year {year}  |  {len(jp2_files)} JP2 file(s)')
    print(f'{"="*60}')

    year_scenes = []
    seen_dates = set()

    for jp2_path in jp2_files:
        fname      = os.path.basename(jp2_path)
        date_match = re.search(r'_(\d{8})T', fname)
        date_str   = date_match.group(1) if date_match else 'unknown'
        if date_str in seen_dates and date_str != "unknown":
            print(f"  [SKIPPED] Duplicate date detected: {date_str}")
            continue
        seen_dates.add(date_str)
        
        if date_str != "unknown" and int(date_str[:4]) != year:
            print(f"  [SKIPPED] File year ({date_str[:4]}) does not match folder year ({year})")
            continue
        print(f'\n  [{date_str}] {fname}')

        try:
            # ── Load image (native resolution, no colour stretching) ──────
            img_rgb, geo_tf, crs, scale = load_jp2(jp2_path)
            H, W = img_rgb.shape[:2]
            print(f'  Image size: {W}x{H} px  (scale={scale:.3f})')

            # ── Run inference at full resolution ──────────────────────────
            prob_map, mining_mask, detections, n_total = run_inference(img_rgb)

            n_mining      = len(detections)
            coverage      = mining_mask.sum() / mining_mask.size * 100
            pixel_size_m  = NATIVE_RES_M / scale
            mining_pixels = int(mining_mask.sum())
            area_km2      = (mining_pixels * pixel_size_m**2) / 1e6

            print(f'  Result: {n_mining:,} mining patches  |  {area_km2:.2f} km2  |  {coverage:.2f}% coverage')

            # ── Save arrays to temp disk (prevents RAM accumulation) ──────
            temp_f = os.path.join(OUTPUT_DIR, f'{year}_{date_str}_temp.npz')
            np.savez_compressed(temp_f, img=img_rgb, prob=prob_map, mask=mining_mask)

            # ── FREE RAM immediately after saving to disk ─────────────────
            del img_rgb, prob_map, mining_mask
            import gc; gc.collect()

            scene = {
                'year'        : year,
                'date'        : date_str,
                'filename'    : fname,
                'n_mining'    : n_mining,
                'n_total'     : n_total,
                'area_km2'    : area_km2,
                'coverage_pct': coverage,
                '_detections' : detections,
                '_temp_file'  : temp_f,
            }
            year_scenes.append(scene)
            all_scenes.append(scene)

        except Exception as e:
            print(f'  ERROR: {e}')
            import traceback; traceback.print_exc()

    if not year_scenes:
        continue

    # ── Pick best scene for this year ─────────────────────────────────
    if SCENE_SELECT == 'max_mining':
        best = max(year_scenes, key=lambda s: s['area_km2'])
    elif SCENE_SELECT == 'median':
        areas_list = [s['area_km2'] for s in year_scenes]
        median_val = sorted(areas_list)[len(areas_list)//2]
        best = min(year_scenes, key=lambda s: abs(s['area_km2'] - median_val))
    else:
        best = year_scenes[0]

    print(f'\n  Best scene for {year}: {best["date"]} ({best["area_km2"]:.2f} km2)')

    # ── Reload ONLY the best scene arrays from disk ───────────────────
    with np.load(best['_temp_file']) as data:
        best_img  = data['img']
        best_prob = data['prob']
        best_mask = data['mask']

    # ── Save overlay + heatmap ────────────────────────────────────────
    overlay = make_overlay(best_img, best_mask)

    save_overlay_fig(
        best_img, overlay, best_mask,
        best['_detections'], year, best['date'],
        os.path.join(OUTPUT_DIR, f'{year}_overlay.png')
    )
    save_heatmap_fig(
        best_img, best_prob, year,
        os.path.join(OUTPUT_DIR, f'{year}_heatmap.png')
    )

    # ── Free the reloaded arrays ───────────────────────────────────────
    # ── Save permanent boolean mask for Expansion Mapping ──
    np.save(os.path.join(OUTPUT_DIR, f'{year}_best_mask.npy'), best_mask)

    del best_img, best_prob, best_mask, overlay
    import gc; gc.collect()

    # ── Save per-year JSON result ─────────────────────────────────────
    result_dict = {k: v for k, v in best.items() if not k.startswith('_')}
    json_path = os.path.join(OUTPUT_DIR, f'{year}_result.json')
    with open(json_path, 'w') as jf:
        json.dump(result_dict, jf, indent=2)

    yearly_results.append(result_dict)

    # ── Clean up all temp .npz files for this year ────────────────────
    for temp_file in glob.glob(os.path.join(OUTPUT_DIR, f'{year}_*_temp.npz')):
        try: os.remove(temp_file)
        except: pass

print(f'\n{"="*60}')
print(f'  BATCH INFERENCE COMPLETE')
print(f'  Years processed: {len(yearly_results)}')
print(f'  Total JP2 files: {len(all_scenes)}')
print(f'{"="*60}')

# ── All scenes CSV ────────────────────────────────────────────────────────
df_all = pd.DataFrame([
    {k: v for k, v in s.items() if not k.startswith('_')}
    for s in all_scenes
])
df_all = df_all.sort_values(['year','date']).reset_index(drop=True)

all_csv = os.path.join(OUTPUT_DIR, 'all_scenes_results.csv')
df_all.to_csv(all_csv, index=False)
print(f'All scenes saved: {all_csv}')
print(df_all[['year','date','n_mining','area_km2','coverage_pct']].to_string(index=False))

# ── Best-per-year CSV ─────────────────────────────────────────────────────
df_best = pd.DataFrame(yearly_results).sort_values('year').reset_index(drop=True)
df_best['change_km2'] = df_best['area_km2'].diff()
df_best['change_pct'] = df_best['area_km2'].pct_change() * 100

best_csv = os.path.join(OUTPUT_DIR, 'yearly_summary.csv')
df_best.to_csv(best_csv, index=False)
print(f'\nYearly summary saved: {best_csv}')

print(f'\n{"="*55}')
print(f'  YEAR-WISE SUMMARY')
print(f'{"="*55}')
print(f'{"Year":<6} {"Date":<10} {"Patches":<10} {"Area km2":<12} {"Change"}')
print('-'*55)
for _, row in df_best.iterrows():
    chg = (f"{row['change_km2']:+.2f} km2 ({row['change_pct']:+.1f}%)"
           if pd.notna(row.get('change_km2')) and pd.notna(row.get('change_pct'))
           else 'baseline')
    print(f"{int(row['year']):<6} {row['date']:<10} "
          f"{int(row['n_mining']):<10} {row['area_km2']:<12.2f} {chg}")
print('='*55)

print(f'\nAll outputs saved to: {OUTPUT_DIR}/')
print('Now run temporal_analysis.ipynb to generate charts.')

if yearly_results:
    n = len(yearly_results)
    fig, axes = plt.subplots(1, n, figsize=(6*n, 6))
    if n == 1: axes = [axes]
    for ax, res in zip(axes, yearly_results):
        img_path = os.path.join(OUTPUT_DIR, f'{res["year"]}_overlay.png')
        if os.path.exists(img_path):
            ax.imshow(plt.imread(img_path))
            ax.set_title(f'{res["year"]}\n{res["area_km2"]:.1f} km2', fontsize=11)
        ax.axis('off')
    plt.suptitle('Mining Detection - Year by Year Overview', fontsize=14)
    plt.tight_layout()
    overview_path = os.path.join(OUTPUT_DIR, 'all_years_overview.png')
    plt.savefig(overview_path, dpi=150, bbox_inches='tight')
    plt.show()
    print(f'Saved: {overview_path}')
# Out:
# ============================================================
#   Year 2021  |  6 JP2 file(s)
# ============================================================
#
#   [20210226] T45QUE_20210226T044741_TCI_10m.jp2
#   Image size: 10980x10980 px  (scale=1.000)
#     0.9%  |  1,000/116,964 patches  |  mining so far: 23
#     1.7%  |  2,000/116,964 patches  |  mining so far: 52
#     2.6%  |  3,000/116,964 patches  |  mining so far: 77
#     3.4%  |  4,000/116,964 patches  |  mining so far: 100
#     4.3%  |  5,000/116,964 patches  |  mining so far: 117
#     5.1%  |  6,000/116,964 patches  |  mining so far: 142
#     6.0%  |  7,000/116,964 patches  |  mining so far: 168
#     6.8%  |  8,000/116,964 patches  |  mining so far: 189
#     7.7%  |  9,000/116,964 patches  |  mining so far: 203
#     8.5%  |  10,000/116,964 patches  |  mining so far: 230
#     9.4%  |  11,000/116,964 patches  |  mining so far: 253
#    10.3%  |  12,000/116,964 patches  |  mining so far: 266
#    11.1%  |  13,000/116,964 patches  |  mining so far: 275
#    12.0%  |  14,000/116,964 patches  |  mining so far: 286
#    12.8%  |  15,000/116,964 patches  |  mining so far: 296
#    13.7%  |  16,000/116,964 patches  |  mining so far: 302
#    14.5%  |  17,000/116,964 patches  |  mining so far: 326
#    15.4%  |  18,000/116,964 patches  |  mining so far: 344
#    16.2%  |  19,000/116,964 patches  |  mining so far: 362
#    17.1%  |  20,000/116,964 patches  |  mining so far: 372
#    18.0%  |  21,000/116,964 patches  |  mining so far: 382
#    18.8%  |  22,000/116,964 patches  |  mining so far: 399
#    19.7%  |  23,000/116,964 patches  |  mining so far: 417
#    20.5%  |  24,000/116,964 patches  |  mining so far: 426
#    21.4%  |  25,000/116,964 patches  |  mining so far: 437
#    22.2%  |  26,000/116,964 patches  |  mining so far: 446
#    23.1%  |  27,000/116,964 patches  |  mining so far: 464
#    23.9%  |  28,000/116,964 patches  |  mining so far: 499
#    24.8%  |  29,000/116,964 patches  |  mining so far: 547
#    25.6%  |  30,000/116,964 patches  |  mining so far: 566
#    26.5%  |  31,000/116,964 patches  |  mining so far: 586
#    27.4%  |  32,000/116,964 patches  |  mining so far: 600
#    28.2%  |  33,000/116,964 patches  |  mining so far: 610
#    29.1%  |  34,000/116,964 patches  |  mining so far: 623
#    29.9%  |  35,000/116,964 patches  |  mining so far: 637
#    30.8%  |  36,000/116,964 patches  |  mining so far: 642
#    31.6%  |  37,000/116,964 patches  |  mining so far: 659
#    32.5%  |  38,000/116,964 patches  |  mining so far: 676
#    33.3%  |  39,000/116,964 patches  |  mining so far: 690
#    34.2%  |  40,000/116,964 patches  |  mining so far: 718
#    35.1%  |  41,000/116,964 patches  |  mining so far: 738
#    35.9%  |  42,000/116,964 patches  |  mining so far: 750
#    36.8%  |  43,000/116,964 patches  |  mining so far: 760
#    37.6%  |  44,000/116,964 patches  |  mining so far: 780
#    38.5%  |  45,000/116,964 patches  |  mining so far: 809
#    39.3%  |  46,000/116,964 patches  |  mining so far: 851
#    40.2%  |  47,000/116,964 patches  |  mining so far: 867
#    41.0%  |  48,000/116,964 patches  |  mining so far: 874
#    41.9%  |  49,000/116,964 patches  |  mining so far: 884
#    42.7%  |  50,000/116,964 patches  |  mining so far: 905
#    43.6%  |  51,000/116,964 patches  |  mining so far: 926
#    44.5%  |  52,000/116,964 patches  |  mining so far: 948
#    45.3%  |  53,000/116,964 patches  |  mining so far: 953
#    46.2%  |  54,000/116,964 patches  |  mining so far: 980
#    47.0%  |  55,000/116,964 patches  |  mining so far: 1,022
#    47.9%  |  56,000/116,964 patches  |  mining so far: 1,063
#    48.7%  |  57,000/116,964 patches  |  mining so far: 1,110
#    49.6%  |  58,000/116,964 patches  |  mining so far: 1,181
#    50.4%  |  59,000/116,964 patches  |  mining so far: 1,261
#    51.3%  |  60,000/116,964 patches  |  mining so far: 1,315
#    52.2%  |  61,000/116,964 patches  |  mining so far: 1,361
#    53.0%  |  62,000/116,964 patches  |  mining so far: 1,386
#    53.9%  |  63,000/116,964 patches  |  mining so far: 1,437
#    54.7%  |  64,000/116,964 patches  |  mining so far: 1,469
#    55.6%  |  65,000/116,964 patches  |  mining so far: 1,488
#    56.4%  |  66,000/116,964 patches  |  mining so far: 1,512
#    57.3%  |  67,000/116,964 patches  |  mining so far: 1,565
#    58.1%  |  68,000/116,964 patches  |  mining so far: 1,593
#    59.0%  |  69,000/116,964 patches  |  mining so far: 1,624
#    59.8%  |  70,000/116,964 patches  |  mining so far: 1,659
#    60.7%  |  71,000/116,964 patches  |  mining so far: 1,716
#    61.6%  |  72,000/116,964 patches  |  mining so far: 1,783
#    62.4%  |  73,000/116,964 patches  |  mining so far: 1,828
#    63.3%  |  74,000/116,964 patches  |  mining so far: 1,892
#    64.1%  |  75,000/116,964 patches  |  mining so far: 1,975
#    65.0%  |  76,000/116,964 patches  |  mining so far: 2,053
#    65.8%  |  77,000/116,964 patches  |  mining so far: 2,107
#    66.7%  |  78,000/116,964 patches  |  mining so far: 2,173
#    67.5%  |  79,000/116,964 patches  |  mining so far: 2,269
#    68.4%  |  80,000/116,964 patches  |  mining so far: 2,370
#    69.3%  |  81,000/116,964 patches  |  mining so far: 2,457
#    70.1%  |  82,000/116,964 patches  |  mining so far: 2,498
#    71.0%  |  83,000/116,964 patches  |  mining so far: 2,548
#    71.8%  |  84,000/116,964 patches  |  mining so far: 2,611
#    72.7%  |  85,000/116,964 patches  |  mining so far: 2,685
#    73.5%  |  86,000/116,964 patches  |  mining so far: 2,764
#    74.4%  |  87,000/116,964 patches  |  mining so far: 2,824
#    75.2%  |  88,000/116,964 patches  |  mining so far: 2,899
#    76.1%  |  89,000/116,964 patches  |  mining so far: 2,931
#    76.9%  |  90,000/116,964 patches  |  mining so far: 2,963
#    77.8%  |  91,000/116,964 patches  |  mining so far: 2,977
#    78.7%  |  92,000/116,964 patches  |  mining so far: 2,995
#    79.5%  |  93,000/116,964 patches  |  mining so far: 3,013
#    80.4%  |  94,000/116,964 patches  |  mining so far: 3,033
#    81.2%  |  95,000/116,964 patches  |  mining so far: 3,066
#    82.1%  |  96,000/116,964 patches  |  mining so far: 3,090
#    82.9%  |  97,000/116,964 patches  |  mining so far: 3,107
#    83.8%  |  98,000/116,964 patches  |  mining so far: 3,128
#    84.6%  |  99,000/116,964 patches  |  mining so far: 3,163
#    85.5%  |  100,000/116,964 patches  |  mining so far: 3,205
#    86.4%  |  101,000/116,964 patches  |  mining so far: 3,229
#    87.2%  |  102,000/116,964 patches  |  mining so far: 3,256
#    88.1%  |  103,000/116,964 patches  |  mining so far: 3,274
#    88.9%  |  104,000/116,964 patches  |  mining so far: 3,293
#    89.8%  |  105,000/116,964 patches  |  mining so far: 3,306
#    90.6%  |  106,000/116,964 patches  |  mining so far: 3,326
#    91.5%  |  107,000/116,964 patches  |  mining so far: 3,338
#    92.3%  |  108,000/116,964 patches  |  mining so far: 3,355
#    93.2%  |  109,000/116,964 patches  |  mining so far: 3,381
#    94.0%  |  110,000/116,964 patches  |  mining so far: 3,400
#    94.9%  |  111,000/116,964 patches  |  mining so far: 3,434
#    95.8%  |  112,000/116,964 patches  |  mining so far: 3,457
#    96.6%  |  113,000/116,964 patches  |  mining so far: 3,482
#    97.5%  |  114,000/116,964 patches  |  mining so far: 3,505
#    98.3%  |  115,000/116,964 patches  |  mining so far: 3,543
#    99.2%  |  116,000/116,964 patches  |  mining so far: 3,562
#   100.0%  |  116,964/116,964 patches  |  mining so far: 3,595
#   Result: 3,595 mining patches  |  191.90 km2  |  1.59% coverage
#
#   [20210328] T45QUE_20210328T044701_TCI_10m.jp2
#   Image size: 10980x10980 px  (scale=1.000)
#     0.9%  |  1,000/116,964 patches  |  mining so far: 9
#     1.7%  |  2,000/116,964 patches  |  mining so far: 18
#     2.6%  |  3,000/116,964 patches  |  mining so far: 22
#     3.4%  |  4,000/116,964 patches  |  mining so far: 42
#     4.3%  |  5,000/116,964 patches  |  mining so far: 48
#     5.1%  |  6,000/116,964 patches  |  mining so far: 68
#     6.0%  |  7,000/116,964 patches  |  mining so far: 88
#     6.8%  |  8,000/116,964 patches  |  mining so far: 104
#     7.7%  |  9,000/116,964 patches  |  mining so far: 121
#     8.5%  |  10,000/116,964 patches  |  mining so far: 139
#     9.4%  |  11,000/116,964 patches  |  mining so far: 151
#    10.3%  |  12,000/116,964 patches  |  mining so far: 160
#    11.1%  |  13,000/116,964 patches  |  mining so far: 167
#    12.0%  |  14,000/116,964 patches  |  mining so far: 175
#    12.8%  |  15,000/116,964 patches  |  mining so far: 195
#    13.7%  |  16,000/116,964 patches  |  mining so far: 204
#    14.5%  |  17,000/116,964 patches  |  mining so far: 211
#    15.4%  |  18,000/116,964 patches  |  mining so far: 225
#    16.2%  |  19,000/116,964 patches  |  mining so far: 243
#    17.1%  |  20,000/116,964 patches  |  mining so far: 245
#    18.0%  |  21,000/116,964 patches  |  mining so far: 250
#    18.8%  |  22,000/116,964 patches  |  mining so far: 263
#    19.7%  |  23,000/116,964 patches  |  mining so far: 281
#    20.5%  |  24,000/116,964 patches  |  mining so far: 286
#    21.4%  |  25,000/116,964 patches  |  mining so far: 298
#    22.2%  |  26,000/116,964 patches  |  mining so far: 309
#    23.1%  |  27,000/116,964 patches  |  mining so far: 321
#    23.9%  |  28,000/116,964 patches  |  mining so far: 339
#    24.8%  |  29,000/116,964 patches  |  mining so far: 377
#    25.6%  |  30,000/116,964 patches  |  mining so far: 391
#    26.5%  |  31,000/116,964 patches  |  mining so far: 396
#    27.4%  |  32,000/116,964 patches  |  mining so far: 410
#    28.2%  |  33,000/116,964 patches  |  mining so far: 425
#    29.1%  |  34,000/116,964 patches  |  mining so far: 429
#    29.9%  |  35,000/116,964 patches  |  mining so far: 440
#    30.8%  |  36,000/116,964 patches  |  mining so far: 450
#    31.6%  |  37,000/116,964 patches  |  mining so far: 456
#    32.5%  |  38,000/116,964 patches  |  mining so far: 463
#    33.3%  |  39,000/116,964 patches  |  mining so far: 479
#    34.2%  |  40,000/116,964 patches  |  mining so far: 501
#    35.1%  |  41,000/116,964 patches  |  mining so far: 515
#    35.9%  |  42,000/116,964 patches  |  mining so far: 524
#    36.8%  |  43,000/116,964 patches  |  mining so far: 534
#    37.6%  |  44,000/116,964 patches  |  mining so far: 551
#    38.5%  |  45,000/116,964 patches  |  mining so far: 576
#    39.3%  |  46,000/116,964 patches  |  mining so far: 608
#    40.2%  |  47,000/116,964 patches  |  mining so far: 622
#    41.0%  |  48,000/116,964 patches  |  mining so far: 631
#    41.9%  |  49,000/116,964 patches  |  mining so far: 639
#    42.7%  |  50,000/116,964 patches  |  mining so far: 655
#    43.6%  |  51,000/116,964 patches  |  mining so far: 680
#    44.5%  |  52,000/116,964 patches  |  mining so far: 696
#    45.3%  |  53,000/116,964 patches  |  mining so far: 703
#    46.2%  |  54,000/116,964 patches  |  mining so far: 734
#    47.0%  |  55,000/116,964 patches  |  mining so far: 771
#    47.9%  |  56,000/116,964 patches  |  mining so far: 810
#    48.7%  |  57,000/116,964 patches  |  mining so far: 848
#    49.6%  |  58,000/116,964 patches  |  mining so far: 913
#    50.4%  |  59,000/116,964 patches  |  mining so far: 984
#    51.3%  |  60,000/116,964 patches  |  mining so far: 1,039
#    52.2%  |  61,000/116,964 patches  |  mining so far: 1,083
#    53.0%  |  62,000/116,964 patches  |  mining so far: 1,110
#    53.9%  |  63,000/116,964 patches  |  mining so far: 1,162
#    54.7%  |  64,000/116,964 patches  |  mining so far: 1,199
#    55.6%  |  65,000/116,964 patches  |  mining so far: 1,217
#    56.4%  |  66,000/116,964 patches  |  mining so far: 1,237
#    57.3%  |  67,000/116,964 patches  |  mining so far: 1,277
#    58.1%  |  68,000/116,964 patches  |  mining so far: 1,298
#    59.0%  |  69,000/116,964 patches  |  mining so far: 1,318
#    59.8%  |  70,000/116,964 patches  |  mining so far: 1,349
#    60.7%  |  71,000/116,964 patches  |  mining so far: 1,397
#    61.6%  |  72,000/116,964 patches  |  mining so far: 1,454
#    62.4%  |  73,000/116,964 patches  |  mining so far: 1,507
#    63.3%  |  74,000/116,964 patches  |  mining so far: 1,573
#    64.1%  |  75,000/116,964 patches  |  mining so far: 1,647
#    65.0%  |  76,000/116,964 patches  |  mining so far: 1,707
#    65.8%  |  77,000/116,964 patches  |  mining so far: 1,754
#    66.7%  |  78,000/116,964 patches  |  mining so far: 1,807
#    67.5%  |  79,000/116,964 patches  |  mining so far: 1,878
#    68.4%  |  80,000/116,964 patches  |  mining so far: 1,972
#    69.3%  |  81,000/116,964 patches  |  mining so far: 2,049
#    70.1%  |  82,000/116,964 patches  |  mining so far: 2,090
#    71.0%  |  83,000/116,964 patches  |  mining so far: 2,137
#    71.8%  |  84,000/116,964 patches  |  mining so far: 2,193
#    72.7%  |  85,000/116,964 patches  |  mining so far: 2,261
#    73.5%  |  86,000/116,964 patches  |  mining so far: 2,337
#    74.4%  |  87,000/116,964 patches  |  mining so far: 2,398
#    75.2%  |  88,000/116,964 patches  |  mining so far: 2,465
#    76.1%  |  89,000/116,964 patches  |  mining so far: 2,500
#    76.9%  |  90,000/116,964 patches  |  mining so far: 2,528
#    77.8%  |  91,000/116,964 patches  |  mining so far: 2,538
#    78.7%  |  92,000/116,964 patches  |  mining so far: 2,553
#    79.5%  |  93,000/116,964 patches  |  mining so far: 2,566
#    80.4%  |  94,000/116,964 patches  |  mining so far: 2,587
#    81.2%  |  95,000/116,964 patches  |  mining so far: 2,620
#    82.1%  |  96,000/116,964 patches  |  mining so far: 2,638
#    82.9%  |  97,000/116,964 patches  |  mining so far: 2,652
#    83.8%  |  98,000/116,964 patches  |  mining so far: 2,678
#    84.6%  |  99,000/116,964 patches  |  mining so far: 2,696
#    85.5%  |  100,000/116,964 patches  |  mining so far: 2,733
#    86.4%  |  101,000/116,964 patches  |  mining so far: 2,762
#    87.2%  |  102,000/116,964 patches  |  mining so far: 2,783
#    88.1%  |  103,000/116,964 patches  |  mining so far: 2,800
#    88.9%  |  104,000/116,964 patches  |  mining so far: 2,812
#    89.8%  |  105,000/116,964 patches  |  mining so far: 2,823
#    90.6%  |  106,000/116,964 patches  |  mining so far: 2,847
#    91.5%  |  107,000/116,964 patches  |  mining so far: 2,866
#    92.3%  |  108,000/116,964 patches  |  mining so far: 2,880
#    93.2%  |  109,000/116,964 patches  |  mining so far: 2,899
#    94.0%  |  110,000/116,964 patches  |  mining so far: 2,913
#    94.9%  |  111,000/116,964 patches  |  mining so far: 2,939
#    95.8%  |  112,000/116,964 patches  |  mining so far: 2,957
#    96.6%  |  113,000/116,964 patches  |  mining so far: 2,974
#    97.5%  |  114,000/116,964 patches  |  mining so far: 2,990
#    98.3%  |  115,000/116,964 patches  |  mining so far: 3,023
#    99.2%  |  116,000/116,964 patches  |  mining so far: 3,046
#   100.0%  |  116,964/116,964 patches  |  mining so far: 3,081
#   Result: 3,081 mining patches  |  153.19 km2  |  1.27% coverage
#
#   [20210427] T45QUE_20210427T044701_TCI_10m.jp2
#   Image size: 10980x10980 px  (scale=1.000)
#     0.9%  |  1,000/116,964 patches  |  mining so far: 18
#     1.7%  |  2,000/116,964 patches  |  mining so far: 38
#     2.6%  |  3,000/116,964 patches  |  mining so far: 48
#     3.4%  |  4,000/116,964 patches  |  mining so far: 68
#     4.3%  |  5,000/116,964 patches  |  mining so far: 82
#     5.1%  |  6,000/116,964 patches  |  mining so far: 109
#     6.0%  |  7,000/116,964 patches  |  mining so far: 133
#     6.8%  |  8,000/116,964 patches  |  mining so far: 151
#     7.7%  |  9,000/116,964 patches  |  mining so far: 163
#     8.5%  |  10,000/116,964 patches  |  mining so far: 172
#     9.4%  |  11,000/116,964 patches  |  mining so far: 178
#    10.3%  |  12,000/116,964 patches  |  mining so far: 183
#    11.1%  |  13,000/116,964 patches  |  mining so far: 190
#    12.0%  |  14,000/116,964 patches  |  mining so far: 197
#    12.8%  |  15,000/116,964 patches  |  mining so far: 206
#    13.7%  |  16,000/116,964 patches  |  mining so far: 207
#    14.5%  |  17,000/116,964 patches  |  mining so far: 211
#    15.4%  |  18,000/116,964 patches  |  mining so far: 219
#    16.2%  |  19,000/116,964 patches  |  mining so far: 226
#    17.1%  |  20,000/116,964 patches  |  mining so far: 230
#    18.0%  |  21,000/116,964 patches  |  mining so far: 239
#    18.8%  |  22,000/116,964 patches  |  mining so far: 256
#    19.7%  |  23,000/116,964 patches  |  mining so far: 266
#    20.5%  |  24,000/116,964 patches  |  mining so far: 269
#    21.4%  |  25,000/116,964 patches  |  mining so far: 275
#    22.2%  |  26,000/116,964 patches  |  mining so far: 277
#    23.1%  |  27,000/116,964 patches  |  mining so far: 281
#    23.9%  |  28,000/116,964 patches  |  mining so far: 293
#    24.8%  |  29,000/116,964 patches  |  mining so far: 321
#    25.6%  |  30,000/116,964 patches  |  mining so far: 332
#    26.5%  |  31,000/116,964 patches  |  mining so far: 339
#    27.4%  |  32,000/116,964 patches  |  mining so far: 347
#    28.2%  |  33,000/116,964 patches  |  mining so far: 351
#    29.1%  |  34,000/116,964 patches  |  mining so far: 357
#    29.9%  |  35,000/116,964 patches  |  mining so far: 360
#    30.8%  |  36,000/116,964 patches  |  mining so far: 366
#    31.6%  |  37,000/116,964 patches  |  mining so far: 373
#    32.5%  |  38,000/116,964 patches  |  mining so far: 386
#    33.3%  |  39,000/116,964 patches  |  mining so far: 395
#    34.2%  |  40,000/116,964 patches  |  mining so far: 420
#    35.1%  |  41,000/116,964 patches  |  mining so far: 435
#    35.9%  |  42,000/116,964 patches  |  mining so far: 446
#    36.8%  |  43,000/116,964 patches  |  mining so far: 449
#    37.6%  |  44,000/116,964 patches  |  mining so far: 469
#    38.5%  |  45,000/116,964 patches  |  mining so far: 495
#    39.3%  |  46,000/116,964 patches  |  mining so far: 530
#    40.2%  |  47,000/116,964 patches  |  mining so far: 550
#    41.0%  |  48,000/116,964 patches  |  mining so far: 566
#    41.9%  |  49,000/116,964 patches  |  mining so far: 576
#    42.7%  |  50,000/116,964 patches  |  mining so far: 594
#    43.6%  |  51,000/116,964 patches  |  mining so far: 619
#    44.5%  |  52,000/116,964 patches  |  mining so far: 631
#    45.3%  |  53,000/116,964 patches  |  mining so far: 645
#    46.2%  |  54,000/116,964 patches  |  mining so far: 682
#    47.0%  |  55,000/116,964 patches  |  mining so far: 721
#    47.9%  |  56,000/116,964 patches  |  mining so far: 771
#    48.7%  |  57,000/116,964 patches  |  mining so far: 817
#    49.6%  |  58,000/116,964 patches  |  mining so far: 886
#    50.4%  |  59,000/116,964 patches  |  mining so far: 970
#    51.3%  |  60,000/116,964 patches  |  mining so far: 1,024
#    52.2%  |  61,000/116,964 patches  |  mining so far: 1,065
#    53.0%  |  62,000/116,964 patches  |  mining so far: 1,099
#    53.9%  |  63,000/116,964 patches  |  mining so far: 1,155
#    54.7%  |  64,000/116,964 patches  |  mining so far: 1,188
#    55.6%  |  65,000/116,964 patches  |  mining so far: 1,206
#    56.4%  |  66,000/116,964 patches  |  mining so far: 1,225
#    57.3%  |  67,000/116,964 patches  |  mining so far: 1,274
#    58.1%  |  68,000/116,964 patches  |  mining so far: 1,297
#    59.0%  |  69,000/116,964 patches  |  mining so far: 1,326
#    59.8%  |  70,000/116,964 patches  |  mining so far: 1,356
#    60.7%  |  71,000/116,964 patches  |  mining so far: 1,419
#    61.6%  |  72,000/116,964 patches  |  mining so far: 1,484
#    62.4%  |  73,000/116,964 patches  |  mining so far: 1,530
#    63.3%  |  74,000/116,964 patches  |  mining so far: 1,591
#    64.1%  |  75,000/116,964 patches  |  mining so far: 1,667
#    65.0%  |  76,000/116,964 patches  |  mining so far: 1,743
#    65.8%  |  77,000/116,964 patches  |  mining so far: 1,802
#    66.7%  |  78,000/116,964 patches  |  mining so far: 1,858
#    67.5%  |  79,000/116,964 patches  |  mining so far: 1,936
#    68.4%  |  80,000/116,964 patches  |  mining so far: 2,039
#    69.3%  |  81,000/116,964 patches  |  mining so far: 2,127
#    70.1%  |  82,000/116,964 patches  |  mining so far: 2,170
#    71.0%  |  83,000/116,964 patches  |  mining so far: 2,215
#    71.8%  |  84,000/116,964 patches  |  mining so far: 2,272
#    72.7%  |  85,000/116,964 patches  |  mining so far: 2,335
#    73.5%  |  86,000/116,964 patches  |  mining so far: 2,407
#    74.4%  |  87,000/116,964 patches  |  mining so far: 2,471
#    75.2%  |  88,000/116,964 patches  |  mining so far: 2,539
#    76.1%  |  89,000/116,964 patches  |  mining so far: 2,570
#    76.9%  |  90,000/116,964 patches  |  mining so far: 2,596
#    77.8%  |  91,000/116,964 patches  |  mining so far: 2,610
#    78.7%  |  92,000/116,964 patches  |  mining so far: 2,618
#    79.5%  |  93,000/116,964 patches  |  mining so far: 2,633
#    80.4%  |  94,000/116,964 patches  |  mining so far: 2,656
#    81.2%  |  95,000/116,964 patches  |  mining so far: 2,689
#    82.1%  |  96,000/116,964 patches  |  mining so far: 2,708
#    82.9%  |  97,000/116,964 patches  |  mining so far: 2,725
#    83.8%  |  98,000/116,964 patches  |  mining so far: 2,743
#    84.6%  |  99,000/116,964 patches  |  mining so far: 2,769
#    85.5%  |  100,000/116,964 patches  |  mining so far: 2,811
#    86.4%  |  101,000/116,964 patches  |  mining so far: 2,826
#    87.2%  |  102,000/116,964 patches  |  mining so far: 2,852
#    88.1%  |  103,000/116,964 patches  |  mining so far: 2,868
#    88.9%  |  104,000/116,964 patches  |  mining so far: 2,877
#    89.8%  |  105,000/116,964 patches  |  mining so far: 2,890
#    90.6%  |  106,000/116,964 patches  |  mining so far: 2,903
#    91.5%  |  107,000/116,964 patches  |  mining so far: 2,908
#    92.3%  |  108,000/116,964 patches  |  mining so far: 2,920
#    93.2%  |  109,000/116,964 patches  |  mining so far: 2,931
#    94.0%  |  110,000/116,964 patches  |  mining so far: 2,948
#    94.9%  |  111,000/116,964 patches  |  mining so far: 2,978
#    95.8%  |  112,000/116,964 patches  |  mining so far: 3,013
#    96.6%  |  113,000/116,964 patches  |  mining so far: 3,033
#    97.5%  |  114,000/116,964 patches  |  mining so far: 3,055
#    98.3%  |  115,000/116,964 patches  |  mining so far: 3,088
#    99.2%  |  116,000/116,964 patches  |  mining so far: 3,115
#   100.0%  |  116,964/116,964 patches  |  mining so far: 3,151
#   Result: 3,151 mining patches  |  176.74 km2  |  1.47% coverage
#
#   [20211024] T45QUE_20211024T044851_TCI_10m.jp2
#   Image size: 10980x10980 px  (scale=1.000)
#     0.9%  |  1,000/116,964 patches  |  mining so far: 5
#     1.7%  |  2,000/116,964 patches  |  mining so far: 10
#     2.6%  |  3,000/116,964 patches  |  mining so far: 11
#     3.4%  |  4,000/116,964 patches  |  mining so far: 11
#     4.3%  |  5,000/116,964 patches  |  mining so far: 11
#     5.1%  |  6,000/116,964 patches  |  mining so far: 11
#     6.0%  |  7,000/116,964 patches  |  mining so far: 11
#     6.8%  |  8,000/116,964 patches  |  mining so far: 11
#     7.7%  |  9,000/116,964 patches  |  mining so far: 11
#     8.5%  |  10,000/116,964 patches  |  mining so far: 11
#     9.4%  |  11,000/116,964 patches  |  mining so far: 12
#    10.3%  |  12,000/116,964 patches  |  mining so far: 13
#    11.1%  |  13,000/116,964 patches  |  mining so far: 13
#    12.0%  |  14,000/116,964 patches  |  mining so far: 13
#    12.8%  |  15,000/116,964 patches  |  mining so far: 14
#    13.7%  |  16,000/116,964 patches  |  mining so far: 15
#    14.5%  |  17,000/116,964 patches  |  mining so far: 15
#    15.4%  |  18,000/116,964 patches  |  mining so far: 15
#    16.2%  |  19,000/116,964 patches  |  mining so far: 15
#    17.1%  |  20,000/116,964 patches  |  mining so far: 15
#    18.0%  |  21,000/116,964 patches  |  mining so far: 16
#    18.8%  |  22,000/116,964 patches  |  mining so far: 16
#    19.7%  |  23,000/116,964 patches  |  mining so far: 16
#    20.5%  |  24,000/116,964 patches  |  mining so far: 16
#    21.4%  |  25,000/116,964 patches  |  mining so far: 17
#    22.2%  |  26,000/116,964 patches  |  mining so far: 18
#    23.1%  |  27,000/116,964 patches  |  mining so far: 18
#    23.9%  |  28,000/116,964 patches  |  mining so far: 21
#    24.8%  |  29,000/116,964 patches  |  mining so far: 23
#    25.6%  |  30,000/116,964 patches  |  mining so far: 23
#    26.5%  |  31,000/116,964 patches  |  mining so far: 25
#    27.4%  |  32,000/116,964 patches  |  mining so far: 26
#    28.2%  |  33,000/116,964 patches  |  mining so far: 26
#    29.1%  |  34,000/116,964 patches  |  mining so far: 26
#    29.9%  |  35,000/116,964 patches  |  mining so far: 26
#    30.8%  |  36,000/116,964 patches  |  mining so far: 26
#    31.6%  |  37,000/116,964 patches  |  mining so far: 28
#    32.5%  |  38,000/116,964 patches  |  mining so far: 31
#    33.3%  |  39,000/116,964 patches  |  mining so far: 33
#    34.2%  |  40,000/116,964 patches  |  mining so far: 36
#    35.1%  |  41,000/116,964 patches  |  mining so far: 39
#    35.9%  |  42,000/116,964 patches  |  mining so far: 40
#    36.8%  |  43,000/116,964 patches  |  mining so far: 41
#    37.6%  |  44,000/116,964 patches  |  mining so far: 53
#    38.5%  |  45,000/116,964 patches  |  mining so far: 66
#    39.3%  |  46,000/116,964 patches  |  mining so far: 75
#    40.2%  |  47,000/116,964 patches  |  mining so far: 75
#    41.0%  |  48,000/116,964 patches  |  mining so far: 77
#    41.9%  |  49,000/116,964 patches  |  mining so far: 78
#    42.7%  |  50,000/116,964 patches  |  mining so far: 86
#    43.6%  |  51,000/116,964 patches  |  mining so far: 103
#    44.5%  |  52,000/116,964 patches  |  mining so far: 114
#    45.3%  |  53,000/116,964 patches  |  mining so far: 116
#    46.2%  |  54,000/116,964 patches  |  mining so far: 134
#    47.0%  |  55,000/116,964 patches  |  mining so far: 158
#    47.9%  |  56,000/116,964 patches  |  mining so far: 188
#    48.7%  |  57,000/116,964 patches  |  mining so far: 230
#    49.6%  |  58,000/116,964 patches  |  mining so far: 284
#    50.4%  |  59,000/116,964 patches  |  mining so far: 320
#    51.3%  |  60,000/116,964 patches  |  mining so far: 342
#    52.2%  |  61,000/116,964 patches  |  mining so far: 356
#    53.0%  |  62,000/116,964 patches  |  mining so far: 369
#    53.9%  |  63,000/116,964 patches  |  mining so far: 387
#    54.7%  |  64,000/116,964 patches  |  mining so far: 403
#    55.6%  |  65,000/116,964 patches  |  mining so far: 419
#    56.4%  |  66,000/116,964 patches  |  mining so far: 434
#    57.3%  |  67,000/116,964 patches  |  mining so far: 475
#    58.1%  |  68,000/116,964 patches  |  mining so far: 488
#    59.0%  |  69,000/116,964 patches  |  mining so far: 498
#    59.8%  |  70,000/116,964 patches  |  mining so far: 520
#    60.7%  |  71,000/116,964 patches  |  mining so far: 560
#    61.6%  |  72,000/116,964 patches  |  mining so far: 621
#    62.4%  |  73,000/116,964 patches  |  mining so far: 656
#    63.3%  |  74,000/116,964 patches  |  mining so far: 709
#    64.1%  |  75,000/116,964 patches  |  mining so far: 761
#    65.0%  |  76,000/116,964 patches  |  mining so far: 811
#    65.8%  |  77,000/116,964 patches  |  mining so far: 863
#    66.7%  |  78,000/116,964 patches  |  mining so far: 911
#    67.5%  |  79,000/116,964 patches  |  mining so far: 982
#    68.4%  |  80,000/116,964 patches  |  mining so far: 1,065
#    69.3%  |  81,000/116,964 patches  |  mining so far: 1,132
#    70.1%  |  82,000/116,964 patches  |  mining so far: 1,157
#    71.0%  |  83,000/116,964 patches  |  mining so far: 1,185
#    71.8%  |  84,000/116,964 patches  |  mining so far: 1,231
#    72.7%  |  85,000/116,964 patches  |  mining so far: 1,294
#    73.5%  |  86,000/116,964 patches  |  mining so far: 1,356
#    74.4%  |  87,000/116,964 patches  |  mining so far: 1,402
#    75.2%  |  88,000/116,964 patches  |  mining so far: 1,451
#    76.1%  |  89,000/116,964 patches  |  mining so far: 1,464
#    76.9%  |  90,000/116,964 patches  |  mining so far: 1,468
#    77.8%  |  91,000/116,964 patches  |  mining so far: 1,471
#    78.7%  |  92,000/116,964 patches  |  mining so far: 1,471
#    79.5%  |  93,000/116,964 patches  |  mining so far: 1,472
#    80.4%  |  94,000/116,964 patches  |  mining so far: 1,475
#    81.2%  |  95,000/116,964 patches  |  mining so far: 1,483
#    82.1%  |  96,000/116,964 patches  |  mining so far: 1,488
#    82.9%  |  97,000/116,964 patches  |  mining so far: 1,490
#    83.8%  |  98,000/116,964 patches  |  mining so far: 1,491
#    84.6%  |  99,000/116,964 patches  |  mining so far: 1,496
#    85.5%  |  100,000/116,964 patches  |  mining so far: 1,522
#    86.4%  |  101,000/116,964 patches  |  mining so far: 1,525
#    87.2%  |  102,000/116,964 patches  |  mining so far: 1,525
#    88.1%  |  103,000/116,964 patches  |  mining so far: 1,526
#    88.9%  |  104,000/116,964 patches  |  mining so far: 1,526
#    89.8%  |  105,000/116,964 patches  |  mining so far: 1,526
#    90.6%  |  106,000/116,964 patches  |  mining so far: 1,526
#    91.5%  |  107,000/116,964 patches  |  mining so far: 1,526
#    92.3%  |  108,000/116,964 patches  |  mining so far: 1,529
#    93.2%  |  109,000/116,964 patches  |  mining so far: 1,531
#    94.0%  |  110,000/116,964 patches  |  mining so far: 1,531
#    94.9%  |  111,000/116,964 patches  |  mining so far: 1,545
#    95.8%  |  112,000/116,964 patches  |  mining so far: 1,555
#    96.6%  |  113,000/116,964 patches  |  mining so far: 1,562
#    97.5%  |  114,000/116,964 patches  |  mining so far: 1,570
#    98.3%  |  115,000/116,964 patches  |  mining so far: 1,588
#    99.2%  |  116,000/116,964 patches  |  mining so far: 1,591
#   100.0%  |  116,964/116,964 patches  |  mining so far: 1,595
#   Result: 1,595 mining patches  |  123.08 km2  |  1.02% coverage
#
#   [20211123] T45QUE_20211123T045121_TCI_10m.jp2
#   Image size: 10980x10980 px  (scale=1.000)
#     0.9%  |  1,000/116,964 patches  |  mining so far: 0
#     1.7%  |  2,000/116,964 patches  |  mining so far: 4
#     2.6%  |  3,000/116,964 patches  |  mining so far: 7
#     3.4%  |  4,000/116,964 patches  |  mining so far: 8
#     4.3%  |  5,000/116,964 patches  |  mining so far: 8
#     5.1%  |  6,000/116,964 patches  |  mining so far: 8
#     6.0%  |  7,000/116,964 patches  |  mining so far: 8
#     6.8%  |  8,000/116,964 patches  |  mining so far: 8
#     7.7%  |  9,000/116,964 patches  |  mining so far: 8
#     8.5%  |  10,000/116,964 patches  |  mining so far: 8
#     9.4%  |  11,000/116,964 patches  |  mining so far: 8
#    10.3%  |  12,000/116,964 patches  |  mining so far: 8
#    11.1%  |  13,000/116,964 patches  |  mining so far: 8
#    12.0%  |  14,000/116,964 patches  |  mining so far: 8
#    12.8%  |  15,000/116,964 patches  |  mining so far: 9
#    13.7%  |  16,000/116,964 patches  |  mining so far: 9
#    14.5%  |  17,000/116,964 patches  |  mining so far: 12
#    15.4%  |  18,000/116,964 patches  |  mining so far: 13
#    16.2%  |  19,000/116,964 patches  |  mining so far: 13
#    17.1%  |  20,000/116,964 patches  |  mining so far: 13
#    18.0%  |  21,000/116,964 patches  |  mining so far: 15
#    18.8%  |  22,000/116,964 patches  |  mining so far: 15
#    19.7%  |  23,000/116,964 patches  |  mining so far: 15
#    20.5%  |  24,000/116,964 patches  |  mining so far: 15
#    21.4%  |  25,000/116,964 patches  |  mining so far: 16
#    22.2%  |  26,000/116,964 patches  |  mining so far: 18
#    23.1%  |  27,000/116,964 patches  |  mining so far: 18
#    23.9%  |  28,000/116,964 patches  |  mining so far: 23
#    24.8%  |  29,000/116,964 patches  |  mining so far: 26
#    25.6%  |  30,000/116,964 patches  |  mining so far: 26
#    26.5%  |  31,000/116,964 patches  |  mining so far: 26
#    27.4%  |  32,000/116,964 patches  |  mining so far: 27
#    28.2%  |  33,000/116,964 patches  |  mining so far: 27
#    29.1%  |  34,000/116,964 patches  |  mining so far: 27
#    29.9%  |  35,000/116,964 patches  |  mining so far: 27
#    30.8%  |  36,000/116,964 patches  |  mining so far: 27
#    31.6%  |  37,000/116,964 patches  |  mining so far: 28
#    32.5%  |  38,000/116,964 patches  |  mining so far: 28
#    33.3%  |  39,000/116,964 patches  |  mining so far: 28
#    34.2%  |  40,000/116,964 patches  |  mining so far: 31
#    35.1%  |  41,000/116,964 patches  |  mining so far: 34
#    35.9%  |  42,000/116,964 patches  |  mining so far: 36
#    36.8%  |  43,000/116,964 patches  |  mining so far: 36
#    37.6%  |  44,000/116,964 patches  |  mining so far: 40
#    38.5%  |  45,000/116,964 patches  |  mining so far: 43
#    39.3%  |  46,000/116,964 patches  |  mining so far: 46
#    40.2%  |  47,000/116,964 patches  |  mining so far: 47
#    41.0%  |  48,000/116,964 patches  |  mining so far: 47
#    41.9%  |  49,000/116,964 patches  |  mining so far: 50
#    42.7%  |  50,000/116,964 patches  |  mining so far: 56
#    43.6%  |  51,000/116,964 patches  |  mining so far: 64
#    44.5%  |  52,000/116,964 patches  |  mining so far: 73
#    45.3%  |  53,000/116,964 patches  |  mining so far: 80
#    46.2%  |  54,000/116,964 patches  |  mining so far: 105
#    47.0%  |  55,000/116,964 patches  |  mining so far: 131
#    47.9%  |  56,000/116,964 patches  |  mining so far: 164
#    48.7%  |  57,000/116,964 patches  |  mining so far: 202
#    49.6%  |  58,000/116,964 patches  |  mining so far: 265
#    50.4%  |  59,000/116,964 patches  |  mining so far: 313
#    51.3%  |  60,000/116,964 patches  |  mining so far: 351
#    52.2%  |  61,000/116,964 patches  |  mining so far: 371
#    53.0%  |  62,000/116,964 patches  |  mining so far: 390
#    53.9%  |  63,000/116,964 patches  |  mining so far: 417
#    54.7%  |  64,000/116,964 patches  |  mining so far: 432
#    55.6%  |  65,000/116,964 patches  |  mining so far: 442
#    56.4%  |  66,000/116,964 patches  |  mining so far: 453
#    57.3%  |  67,000/116,964 patches  |  mining so far: 491
#    58.1%  |  68,000/116,964 patches  |  mining so far: 505
#    59.0%  |  69,000/116,964 patches  |  mining so far: 525
#    59.8%  |  70,000/116,964 patches  |  mining so far: 549
#    60.7%  |  71,000/116,964 patches  |  mining so far: 588
#    61.6%  |  72,000/116,964 patches  |  mining so far: 635
#    62.4%  |  73,000/116,964 patches  |  mining so far: 669
#    63.3%  |  74,000/116,964 patches  |  mining so far: 725
#    64.1%  |  75,000/116,964 patches  |  mining so far: 777
#    65.0%  |  76,000/116,964 patches  |  mining so far: 832
#    65.8%  |  77,000/116,964 patches  |  mining so far: 887
#    66.7%  |  78,000/116,964 patches  |  mining so far: 934
#    67.5%  |  79,000/116,964 patches  |  mining so far: 1,004
#    68.4%  |  80,000/116,964 patches  |  mining so far: 1,085
#    69.3%  |  81,000/116,964 patches  |  mining so far: 1,154
#    70.1%  |  82,000/116,964 patches  |  mining so far: 1,181
#    71.0%  |  83,000/116,964 patches  |  mining so far: 1,218
#    71.8%  |  84,000/116,964 patches  |  mining so far: 1,261
#    72.7%  |  85,000/116,964 patches  |  mining so far: 1,320
#    73.5%  |  86,000/116,964 patches  |  mining so far: 1,373
#    74.4%  |  87,000/116,964 patches  |  mining so far: 1,414
#    75.2%  |  88,000/116,964 patches  |  mining so far: 1,462
#    76.1%  |  89,000/116,964 patches  |  mining so far: 1,472
#    76.9%  |  90,000/116,964 patches  |  mining so far: 1,480
#    77.8%  |  91,000/116,964 patches  |  mining so far: 1,483
#    78.7%  |  92,000/116,964 patches  |  mining so far: 1,493
#    79.5%  |  93,000/116,964 patches  |  mining so far: 1,500
#    80.4%  |  94,000/116,964 patches  |  mining so far: 1,502
#    81.2%  |  95,000/116,964 patches  |  mining so far: 1,511
#    82.1%  |  96,000/116,964 patches  |  mining so far: 1,517
#    82.9%  |  97,000/116,964 patches  |  mining so far: 1,528
#    83.8%  |  98,000/116,964 patches  |  mining so far: 1,529
#    84.6%  |  99,000/116,964 patches  |  mining so far: 1,537
#    85.5%  |  100,000/116,964 patches  |  mining so far: 1,562
#    86.4%  |  101,000/116,964 patches  |  mining so far: 1,567
#    87.2%  |  102,000/116,964 patches  |  mining so far: 1,581
#    88.1%  |  103,000/116,964 patches  |  mining so far: 1,592
#    88.9%  |  104,000/116,964 patches  |  mining so far: 1,593
#    89.8%  |  105,000/116,964 patches  |  mining so far: 1,599
#    90.6%  |  106,000/116,964 patches  |  mining so far: 1,602
#    91.5%  |  107,000/116,964 patches  |  mining so far: 1,604
#    92.3%  |  108,000/116,964 patches  |  mining so far: 1,613
#    93.2%  |  109,000/116,964 patches  |  mining so far: 1,616
#    94.0%  |  110,000/116,964 patches  |  mining so far: 1,621
#    94.9%  |  111,000/116,964 patches  |  mining so far: 1,634
#    95.8%  |  112,000/116,964 patches  |  mining so far: 1,645
#    96.6%  |  113,000/116,964 patches  |  mining so far: 1,652
#    97.5%  |  114,000/116,964 patches  |  mining so far: 1,666
#    98.3%  |  115,000/116,964 patches  |  mining so far: 1,685
#    99.2%  |  116,000/116,964 patches  |  mining so far: 1,687
#   100.0%  |  116,964/116,964 patches  |  mining so far: 1,694
#   Result: 1,694 mining patches  |  124.72 km2  |  1.03% coverage
#
#   [20211223] T45QUE_20211223T045221_TCI_10m.jp2
#   Image size: 10980x10980 px  (scale=1.000)
#     0.9%  |  1,000/116,964 patches  |  mining so far: 3
#     1.7%  |  2,000/116,964 patches  |  mining so far: 5
#     2.6%  |  3,000/116,964 patches  |  mining so far: 9
#     3.4%  |  4,000/116,964 patches  |  mining so far: 12
#     4.3%  |  5,000/116,964 patches  |  mining so far: 14
#     5.1%  |  6,000/116,964 patches  |  mining so far: 16
#     6.0%  |  7,000/116,964 patches  |  mining so far: 19
#     6.8%  |  8,000/116,964 patches  |  mining so far: 21
#     7.7%  |  9,000/116,964 patches  |  mining so far: 22
#     8.5%  |  10,000/116,964 patches  |  mining so far: 23
#     9.4%  |  11,000/116,964 patches  |  mining so far: 25
#    10.3%  |  12,000/116,964 patches  |  mining so far: 26
#    11.1%  |  13,000/116,964 patches  |  mining so far: 28
#    12.0%  |  14,000/116,964 patches  |  mining so far: 28
#    12.8%  |  15,000/116,964 patches  |  mining so far: 28
#    13.7%  |  16,000/116,964 patches  |  mining so far: 28
#    14.5%  |  17,000/116,964 patches  |  mining so far: 29
#    15.4%  |  18,000/116,964 patches  |  mining so far: 30
#    16.2%  |  19,000/116,964 patches  |  mining so far: 30
#    17.1%  |  20,000/116,964 patches  |  mining so far: 30
#    18.0%  |  21,000/116,964 patches  |  mining so far: 30
#    18.8%  |  22,000/116,964 patches  |  mining so far: 30
#    19.7%  |  23,000/116,964 patches  |  mining so far: 30
#    20.5%  |  24,000/116,964 patches  |  mining so far: 30
#    21.4%  |  25,000/116,964 patches  |  mining so far: 32
#    22.2%  |  26,000/116,964 patches  |  mining so far: 33
#    23.1%  |  27,000/116,964 patches  |  mining so far: 33
#    23.9%  |  28,000/116,964 patches  |  mining so far: 37
#    24.8%  |  29,000/116,964 patches  |  mining so far: 40
#    25.6%  |  30,000/116,964 patches  |  mining so far: 40
#    26.5%  |  31,000/116,964 patches  |  mining so far: 44
#    27.4%  |  32,000/116,964 patches  |  mining so far: 47
#    28.2%  |  33,000/116,964 patches  |  mining so far: 47
#    29.1%  |  34,000/116,964 patches  |  mining so far: 47
#    29.9%  |  35,000/116,964 patches  |  mining so far: 47
#    30.8%  |  36,000/116,964 patches  |  mining so far: 47
#    31.6%  |  37,000/116,964 patches  |  mining so far: 47
#    32.5%  |  38,000/116,964 patches  |  mining so far: 51
#    33.3%  |  39,000/116,964 patches  |  mining so far: 57
#    34.2%  |  40,000/116,964 patches  |  mining so far: 71
#    35.1%  |  41,000/116,964 patches  |  mining so far: 81
#    35.9%  |  42,000/116,964 patches  |  mining so far: 84
#    36.8%  |  43,000/116,964 patches  |  mining so far: 86
#    37.6%  |  44,000/116,964 patches  |  mining so far: 99
#    38.5%  |  45,000/116,964 patches  |  mining so far: 116
#    39.3%  |  46,000/116,964 patches  |  mining so far: 141
#    40.2%  |  47,000/116,964 patches  |  mining so far: 144
#    41.0%  |  48,000/116,964 patches  |  mining so far: 147
#    41.9%  |  49,000/116,964 patches  |  mining so far: 152
#    42.7%  |  50,000/116,964 patches  |  mining so far: 165
#    43.6%  |  51,000/116,964 patches  |  mining so far: 185
#    44.5%  |  52,000/116,964 patches  |  mining so far: 196
#    45.3%  |  53,000/116,964 patches  |  mining so far: 203
#    46.2%  |  54,000/116,964 patches  |  mining so far: 232
#    47.0%  |  55,000/116,964 patches  |  mining so far: 259
#    47.9%  |  56,000/116,964 patches  |  mining so far: 291
#    48.7%  |  57,000/116,964 patches  |  mining so far: 331
#    49.6%  |  58,000/116,964 patches  |  mining so far: 393
#    50.4%  |  59,000/116,964 patches  |  mining so far: 461
#    51.3%  |  60,000/116,964 patches  |  mining so far: 511
#    52.2%  |  61,000/116,964 patches  |  mining so far: 543
#    53.0%  |  62,000/116,964 patches  |  mining so far: 561
#    53.9%  |  63,000/116,964 patches  |  mining so far: 592
#    54.7%  |  64,000/116,964 patches  |  mining so far: 616
#    55.6%  |  65,000/116,964 patches  |  mining so far: 626
#    56.4%  |  66,000/116,964 patches  |  mining so far: 643
#    57.3%  |  67,000/116,964 patches  |  mining so far: 683
#    58.1%  |  68,000/116,964 patches  |  mining so far: 697
#    59.0%  |  69,000/116,964 patches  |  mining so far: 721
#    59.8%  |  70,000/116,964 patches  |  mining so far: 755
#    60.7%  |  71,000/116,964 patches  |  mining so far: 803
#    61.6%  |  72,000/116,964 patches  |  mining so far: 871
#    62.4%  |  73,000/116,964 patches  |  mining so far: 918
#    63.3%  |  74,000/116,964 patches  |  mining so far: 991
#    64.1%  |  75,000/116,964 patches  |  mining so far: 1,058
#    65.0%  |  76,000/116,964 patches  |  mining so far: 1,113
#    65.8%  |  77,000/116,964 patches  |  mining so far: 1,167
#    66.7%  |  78,000/116,964 patches  |  mining so far: 1,219
#    67.5%  |  79,000/116,964 patches  |  mining so far: 1,304
#    68.4%  |  80,000/116,964 patches  |  mining so far: 1,389
#    69.3%  |  81,000/116,964 patches  |  mining so far: 1,472
#    70.1%  |  82,000/116,964 patches  |  mining so far: 1,511
#    71.0%  |  83,000/116,964 patches  |  mining so far: 1,552
#    71.8%  |  84,000/116,964 patches  |  mining so far: 1,598
#    72.7%  |  85,000/116,964 patches  |  mining so far: 1,674
#    73.5%  |  86,000/116,964 patches  |  mining so far: 1,747
#    74.4%  |  87,000/116,964 patches  |  mining so far: 1,800
#    75.2%  |  88,000/116,964 patches  |  mining so far: 1,858
#    76.1%  |  89,000/116,964 patches  |  mining so far: 1,877
#    76.9%  |  90,000/116,964 patches  |  mining so far: 1,889
#    77.8%  |  91,000/116,964 patches  |  mining so far: 1,895
#    78.7%  |  92,000/116,964 patches  |  mining so far: 1,907
#    79.5%  |  93,000/116,964 patches  |  mining so far: 1,926
#    80.4%  |  94,000/116,964 patches  |  mining so far: 1,937
#    81.2%  |  95,000/116,964 patches  |  mining so far: 1,953
#    82.1%  |  96,000/116,964 patches  |  mining so far: 1,973
#    82.9%  |  97,000/116,964 patches  |  mining so far: 1,995
#    83.8%  |  98,000/116,964 patches  |  mining so far: 1,996
#    84.6%  |  99,000/116,964 patches  |  mining so far: 2,005
#    85.5%  |  100,000/116,964 patches  |  mining so far: 2,037
#    86.4%  |  101,000/116,964 patches  |  mining so far: 2,060
#    87.2%  |  102,000/116,964 patches  |  mining so far: 2,087
#    88.1%  |  103,000/116,964 patches  |  mining so far: 2,103
#    88.9%  |  104,000/116,964 patches  |  mining so far: 2,110
#    89.8%  |  105,000/116,964 patches  |  mining so far: 2,117
#    90.6%  |  106,000/116,964 patches  |  mining so far: 2,123
#    91.5%  |  107,000/116,964 patches  |  mining so far: 2,126
#    92.3%  |  108,000/116,964 patches  |  mining so far: 2,140
#    93.2%  |  109,000/116,964 patches  |  mining so far: 2,152
#    94.0%  |  110,000/116,964 patches  |  mining so far: 2,163
#    94.9%  |  111,000/116,964 patches  |  mining so far: 2,184
#    95.8%  |  112,000/116,964 patches  |  mining so far: 2,208
#    96.6%  |  113,000/116,964 patches  |  mining so far: 2,225
#    97.5%  |  114,000/116,964 patches  |  mining so far: 2,259
#    98.3%  |  115,000/116,964 patches  |  mining so far: 2,293
#    99.2%  |  116,000/116,964 patches  |  mining so far: 2,309
#   100.0%  |  116,964/116,964 patches  |  mining so far: 2,327
#   Result: 2,327 mining patches  |  155.96 km2  |  1.29% coverage
#
#   Best scene for 2021: 20211223 (155.96 km2)
#   Saved overlay: inference_output/temporal\2021_overlay.png
#   Saved heatmap : inference_output/temporal\2021_heatmap.png
#
# ============================================================
#   Year 2022  |  6 JP2 file(s)
# ============================================================
#
#   [20220102] T45QUE_20220102T045211_TCI_10m.jp2
#   Image size: 10980x10980 px  (scale=1.000)
#     0.9%  |  1,000/116,964 patches  |  mining so far: 14
#     1.7%  |  2,000/116,964 patches  |  mining so far: 24
#     2.6%  |  3,000/116,964 patches  |  mining so far: 28
#     3.4%  |  4,000/116,964 patches  |  mining so far: 37
#     4.3%  |  5,000/116,964 patches  |  mining so far: 42
#     5.1%  |  6,000/116,964 patches  |  mining so far: 45
#     6.0%  |  7,000/116,964 patches  |  mining so far: 48
#     6.8%  |  8,000/116,964 patches  |  mining so far: 55
#     7.7%  |  9,000/116,964 patches  |  mining so far: 58
#     8.5%  |  10,000/116,964 patches  |  mining so far: 62
#     9.4%  |  11,000/116,964 patches  |  mining so far: 63
#    10.3%  |  12,000/116,964 patches  |  mining so far: 65
#    11.1%  |  13,000/116,964 patches  |  mining so far: 70
#    12.0%  |  14,000/116,964 patches  |  mining so far: 70
#    12.8%  |  15,000/116,964 patches  |  mining so far: 71
#    13.7%  |  16,000/116,964 patches  |  mining so far: 71
#    14.5%  |  17,000/116,964 patches  |  mining so far: 71
#    15.4%  |  18,000/116,964 patches  |  mining so far: 73
#    16.2%  |  19,000/116,964 patches  |  mining so far: 75
#    17.1%  |  20,000/116,964 patches  |  mining so far: 76
#    18.0%  |  21,000/116,964 patches  |  mining so far: 76
#    18.8%  |  22,000/116,964 patches  |  mining so far: 76
#    19.7%  |  23,000/116,964 patches  |  mining so far: 77
#    20.5%  |  24,000/116,964 patches  |  mining so far: 79
#    21.4%  |  25,000/116,964 patches  |  mining so far: 82
#    22.2%  |  26,000/116,964 patches  |  mining so far: 83
#    23.1%  |  27,000/116,964 patches  |  mining so far: 84
#    23.9%  |  28,000/116,964 patches  |  mining so far: 87
#    24.8%  |  29,000/116,964 patches  |  mining so far: 89
#    25.6%  |  30,000/116,964 patches  |  mining so far: 93
#    26.5%  |  31,000/116,964 patches  |  mining so far: 95
#    27.4%  |  32,000/116,964 patches  |  mining so far: 97
#    28.2%  |  33,000/116,964 patches  |  mining so far: 98
#    29.1%  |  34,000/116,964 patches  |  mining so far: 99
#    29.9%  |  35,000/116,964 patches  |  mining so far: 99
#    30.8%  |  36,000/116,964 patches  |  mining so far: 99
#    31.6%  |  37,000/116,964 patches  |  mining so far: 100
#    32.5%  |  38,000/116,964 patches  |  mining so far: 104
#    33.3%  |  39,000/116,964 patches  |  mining so far: 109
#    34.2%  |  40,000/116,964 patches  |  mining so far: 125
#    35.1%  |  41,000/116,964 patches  |  mining so far: 133
#    35.9%  |  42,000/116,964 patches  |  mining so far: 135
#    36.8%  |  43,000/116,964 patches  |  mining so far: 140
#    37.6%  |  44,000/116,964 patches  |  mining so far: 154
#    38.5%  |  45,000/116,964 patches  |  mining so far: 168
#    39.3%  |  46,000/116,964 patches  |  mining so far: 195
#    40.2%  |  47,000/116,964 patches  |  mining so far: 202
#    41.0%  |  48,000/116,964 patches  |  mining so far: 207
#    41.9%  |  49,000/116,964 patches  |  mining so far: 214
#    42.7%  |  50,000/116,964 patches  |  mining so far: 225
#    43.6%  |  51,000/116,964 patches  |  mining so far: 244
#    44.5%  |  52,000/116,964 patches  |  mining so far: 255
#    45.3%  |  53,000/116,964 patches  |  mining so far: 261
#    46.2%  |  54,000/116,964 patches  |  mining so far: 294
#    47.0%  |  55,000/116,964 patches  |  mining so far: 322
#    47.9%  |  56,000/116,964 patches  |  mining so far: 352
#    48.7%  |  57,000/116,964 patches  |  mining so far: 394
#    49.6%  |  58,000/116,964 patches  |  mining so far: 461
#    50.4%  |  59,000/116,964 patches  |  mining so far: 517
#    51.3%  |  60,000/116,964 patches  |  mining so far: 558
#    52.2%  |  61,000/116,964 patches  |  mining so far: 590
#    53.0%  |  62,000/116,964 patches  |  mining so far: 616
#    53.9%  |  63,000/116,964 patches  |  mining so far: 647
#    54.7%  |  64,000/116,964 patches  |  mining so far: 668
#    55.6%  |  65,000/116,964 patches  |  mining so far: 678
#    56.4%  |  66,000/116,964 patches  |  mining so far: 690
#    57.3%  |  67,000/116,964 patches  |  mining so far: 733
#    58.1%  |  68,000/116,964 patches  |  mining so far: 745
#    59.0%  |  69,000/116,964 patches  |  mining so far: 766
#    59.8%  |  70,000/116,964 patches  |  mining so far: 798
#    60.7%  |  71,000/116,964 patches  |  mining so far: 848
#    61.6%  |  72,000/116,964 patches  |  mining so far: 905
#    62.4%  |  73,000/116,964 patches  |  mining so far: 945
#    63.3%  |  74,000/116,964 patches  |  mining so far: 1,008
#    64.1%  |  75,000/116,964 patches  |  mining so far: 1,085
#    65.0%  |  76,000/116,964 patches  |  mining so far: 1,142
#    65.8%  |  77,000/116,964 patches  |  mining so far: 1,199
#    66.7%  |  78,000/116,964 patches  |  mining so far: 1,248
# ...
#    14.5%  |  17,000/116,964 patches  |  mining so far: 33
#    15.4%  |  18,000/116,964 patches  |  mining so far: 36
#    16.2%  |  19,000/116,964 patches  |  mining so far: 36
#    17.1%  |  20,000/116,964 patches  |  mining so far: 36
#    18.0%  |  21,000/116,964 patches  |  mining so far: 37
#    18.8%  |  22,000/116,964 patches  |  mining so far: 37
#    19.7%  |  23,000/116,964 patches  |  mining so far: 37
#    20.5%  |  24,000/116,964 patches  |  mining so far: 37
#    21.4%  |  25,000/116,964 patches  |  mining so far: 39
#    22.2%  |  26,000/116,964 patches  |  mining so far: 40
#    23.1%  |  27,000/116,964 patches  |  mining so far: 41
#    23.9%  |  28,000/116,964 patches  |  mining so far: 50
#    24.8%  |  29,000/116,964 patches  |  mining so far: 56
#    25.6%  |  30,000/116,964 patches  |  mining so far: 59
#    26.5%  |  31,000/116,964 patches  |  mining so far: 63
#    27.4%  |  32,000/116,964 patches  |  mining so far: 64
#    28.2%  |  33,000/116,964 patches  |  mining so far: 64
#    29.1%  |  34,000/116,964 patches  |  mining so far: 64
#    29.9%  |  35,000/116,964 patches  |  mining so far: 65
#    30.8%  |  36,000/116,964 patches  |  mining so far: 65
#    31.6%  |  37,000/116,964 patches  |  mining so far: 66
#    32.5%  |  38,000/116,964 patches  |  mining so far: 71
#    33.3%  |  39,000/116,964 patches  |  mining so far: 77
#    34.2%  |  40,000/116,964 patches  |  mining so far: 91
#    35.1%  |  41,000/116,964 patches  |  mining so far: 97
#    35.9%  |  42,000/116,964 patches  |  mining so far: 97
#    36.8%  |  43,000/116,964 patches  |  mining so far: 98
#    37.6%  |  44,000/116,964 patches  |  mining so far: 110
#    38.5%  |  45,000/116,964 patches  |  mining so far: 126
#    39.3%  |  46,000/116,964 patches  |  mining so far: 153
#    40.2%  |  47,000/116,964 patches  |  mining so far: 157
#    41.0%  |  48,000/116,964 patches  |  mining so far: 161
#    41.9%  |  49,000/116,964 patches  |  mining so far: 169
#    42.7%  |  50,000/116,964 patches  |  mining so far: 188
#    43.6%  |  51,000/116,964 patches  |  mining so far: 202
#    44.5%  |  52,000/116,964 patches  |  mining so far: 220
#    45.3%  |  53,000/116,964 patches  |  mining so far: 230
#    46.2%  |  54,000/116,964 patches  |  mining so far: 259
#    47.0%  |  55,000/116,964 patches  |  mining so far: 294
#    47.9%  |  56,000/116,964 patches  |  mining so far: 329
#    48.7%  |  57,000/116,964 patches  |  mining so far: 378
#    49.6%  |  58,000/116,964 patches  |  mining so far: 455
#    50.4%  |  59,000/116,964 patches  |  mining so far: 515
#    51.3%  |  60,000/116,964 patches  |  mining so far: 562
#    52.2%  |  61,000/116,964 patches  |  mining so far: 593
#    53.0%  |  62,000/116,964 patches  |  mining so far: 611
#    53.9%  |  63,000/116,964 patches  |  mining so far: 641
#    54.7%  |  64,000/116,964 patches  |  mining so far: 668
#    55.6%  |  65,000/116,964 patches  |  mining so far: 684
#    56.4%  |  66,000/116,964 patches  |  mining so far: 706
#    57.3%  |  67,000/116,964 patches  |  mining so far: 746
#    58.1%  |  68,000/116,964 patches  |  mining so far: 762
#    59.0%  |  69,000/116,964 patches  |  mining so far: 794
#    59.8%  |  70,000/116,964 patches  |  mining so far: 833
#    60.7%  |  71,000/116,964 patches  |  mining so far: 882
#    61.6%  |  72,000/116,964 patches  |  mining so far: 951
#    62.4%  |  73,000/116,964 patches  |  mining so far: 1,016
#    63.3%  |  74,000/116,964 patches  |  mining so far: 1,107
#    64.1%  |  75,000/116,964 patches  |  mining so far: 1,209
#    65.0%  |  76,000/116,964 patches  |  mining so far: 1,298
#    65.8%  |  77,000/116,964 patches  |  mining so far: 1,374
#    66.7%  |  78,000/116,964 patches  |  mining so far: 1,461
#    67.5%  |  79,000/116,964 patches  |  mining so far: 1,560
#    68.4%  |  80,000/116,964 patches  |  mining so far: 1,670
#    69.3%  |  81,000/116,964 patches  |  mining so far: 1,754
#    70.1%  |  82,000/116,964 patches  |  mining so far: 1,795
#    71.0%  |  83,000/116,964 patches  |  mining so far: 1,838
#    71.8%  |  84,000/116,964 patches  |  mining so far: 1,898
#    72.7%  |  85,000/116,964 patches  |  mining so far: 1,987
#    73.5%  |  86,000/116,964 patches  |  mining so far: 2,062
#    74.4%  |  87,000/116,964 patches  |  mining so far: 2,136
#    75.2%  |  88,000/116,964 patches  |  mining so far: 2,210
#    76.1%  |  89,000/116,964 patches  |  mining so far: 2,241
#    76.9%  |  90,000/116,964 patches  |  mining so far: 2,258
#    77.8%  |  91,000/116,964 patches  |  mining so far: 2,278
#    78.7%  |  92,000/116,964 patches  |  mining so far: 2,300
#    79.5%  |  93,000/116,964 patches  |  mining so far: 2,318
#    80.4%  |  94,000/116,964 patches  |  mining so far: 2,322
#    81.2%  |  95,000/116,964 patches  |  mining so far: 2,340
#    82.1%  |  96,000/116,964 patches  |  mining so far: 2,364
#    82.9%  |  97,000/116,964 patches  |  mining so far: 2,374
#    83.8%  |  98,000/116,964 patches  |  mining so far: 2,380
#    84.6%  |  99,000/116,964 patches  |  mining so far: 2,392
#    85.5%  |  100,000/116,964 patches  |  mining so far: 2,432
#    86.4%  |  101,000/116,964 patches  |  mining so far: 2,457
#    87.2%  |  102,000/116,964 patches  |  mining so far: 2,478
#    88.1%  |  103,000/116,964 patches  |  mining so far: 2,507
#    88.9%  |  104,000/116,964 patches  |  mining so far: 2,525
#    89.8%  |  105,000/116,964 patches  |  mining so far: 2,533
#    90.6%  |  106,000/116,964 patches  |  mining so far: 2,542
#    91.5%  |  107,000/116,964 patches  |  mining so far: 2,551
#    92.3%  |  108,000/116,964 patches  |  mining so far: 2,575
#    93.2%  |  109,000/116,964 patches  |  mining so far: 2,599
#    94.0%  |  110,000/116,964 patches  |  mining so far: 2,612
#    94.9%  |  111,000/116,964 patches  |  mining so far: 2,639
#    95.8%  |  112,000/116,964 patches  |  mining so far: 2,667
#    96.6%  |  113,000/116,964 patches  |  mining so far: 2,690
#    97.5%  |  114,000/116,964 patches  |  mining so far: 2,716
#    98.3%  |  115,000/116,964 patches  |  mining so far: 2,754
#    99.2%  |  116,000/116,964 patches  |  mining so far: 2,768
#   100.0%  |  116,964/116,964 patches  |  mining so far: 2,788
#   Result: 2,788 mining patches  |  198.96 km2  |  1.65% coverage
#
#   [20251224] T45QUE_20251224T045241_TCI_10m.jp2
#   Image size: 10980x10980 px  (scale=1.000)
#     0.9%  |  1,000/116,964 patches  |  mining so far: 8
#     1.7%  |  2,000/116,964 patches  |  mining so far: 12
#     2.6%  |  3,000/116,964 patches  |  mining so far: 21
#     3.4%  |  4,000/116,964 patches  |  mining so far: 27
#     4.3%  |  5,000/116,964 patches  |  mining so far: 33
#     5.1%  |  6,000/116,964 patches  |  mining so far: 43
#     6.0%  |  7,000/116,964 patches  |  mining so far: 45
#     6.8%  |  8,000/116,964 patches  |  mining so far: 47
#     7.7%  |  9,000/116,964 patches  |  mining so far: 52
#     8.5%  |  10,000/116,964 patches  |  mining so far: 58
#     9.4%  |  11,000/116,964 patches  |  mining so far: 66
#    10.3%  |  12,000/116,964 patches  |  mining so far: 69
#    11.1%  |  13,000/116,964 patches  |  mining so far: 74
#    12.0%  |  14,000/116,964 patches  |  mining so far: 78
#    12.8%  |  15,000/116,964 patches  |  mining so far: 79
#    13.7%  |  16,000/116,964 patches  |  mining so far: 79
#    14.5%  |  17,000/116,964 patches  |  mining so far: 82
#    15.4%  |  18,000/116,964 patches  |  mining so far: 83
#    16.2%  |  19,000/116,964 patches  |  mining so far: 88
#    17.1%  |  20,000/116,964 patches  |  mining so far: 91
#    18.0%  |  21,000/116,964 patches  |  mining so far: 94
#    18.8%  |  22,000/116,964 patches  |  mining so far: 96
#    19.7%  |  23,000/116,964 patches  |  mining so far: 98
#    20.5%  |  24,000/116,964 patches  |  mining so far: 98
#    21.4%  |  25,000/116,964 patches  |  mining so far: 101
#    22.2%  |  26,000/116,964 patches  |  mining so far: 105
#    23.1%  |  27,000/116,964 patches  |  mining so far: 112
#    23.9%  |  28,000/116,964 patches  |  mining so far: 124
#    24.8%  |  29,000/116,964 patches  |  mining so far: 137
#    25.6%  |  30,000/116,964 patches  |  mining so far: 140
#    26.5%  |  31,000/116,964 patches  |  mining so far: 141
#    27.4%  |  32,000/116,964 patches  |  mining so far: 148
#    28.2%  |  33,000/116,964 patches  |  mining so far: 150
#    29.1%  |  34,000/116,964 patches  |  mining so far: 150
#    29.9%  |  35,000/116,964 patches  |  mining so far: 152
#    30.8%  |  36,000/116,964 patches  |  mining so far: 154
#    31.6%  |  37,000/116,964 patches  |  mining so far: 161
#    32.5%  |  38,000/116,964 patches  |  mining so far: 173
#    33.3%  |  39,000/116,964 patches  |  mining so far: 187
#    34.2%  |  40,000/116,964 patches  |  mining so far: 206
#    35.1%  |  41,000/116,964 patches  |  mining so far: 216
#    35.9%  |  42,000/116,964 patches  |  mining so far: 224
#    36.8%  |  43,000/116,964 patches  |  mining so far: 227
#    37.6%  |  44,000/116,964 patches  |  mining so far: 247
#    38.5%  |  45,000/116,964 patches  |  mining so far: 264
#    39.3%  |  46,000/116,964 patches  |  mining so far: 290
#    40.2%  |  47,000/116,964 patches  |  mining so far: 298
#    41.0%  |  48,000/116,964 patches  |  mining so far: 300
#    41.9%  |  49,000/116,964 patches  |  mining so far: 321
#    42.7%  |  50,000/116,964 patches  |  mining so far: 337
#    43.6%  |  51,000/116,964 patches  |  mining so far: 348
#    44.5%  |  52,000/116,964 patches  |  mining so far: 355
#    45.3%  |  53,000/116,964 patches  |  mining so far: 366
#    46.2%  |  54,000/116,964 patches  |  mining so far: 388
#    47.0%  |  55,000/116,964 patches  |  mining so far: 417
#    47.9%  |  56,000/116,964 patches  |  mining so far: 457
#    48.7%  |  57,000/116,964 patches  |  mining so far: 510
#    49.6%  |  58,000/116,964 patches  |  mining so far: 580
#    50.4%  |  59,000/116,964 patches  |  mining so far: 642
#    51.3%  |  60,000/116,964 patches  |  mining so far: 687
#    52.2%  |  61,000/116,964 patches  |  mining so far: 706
#    53.0%  |  62,000/116,964 patches  |  mining so far: 724
#    53.9%  |  63,000/116,964 patches  |  mining so far: 750
#    54.7%  |  64,000/116,964 patches  |  mining so far: 780
#    55.6%  |  65,000/116,964 patches  |  mining so far: 793
#    56.4%  |  66,000/116,964 patches  |  mining so far: 806
#    57.3%  |  67,000/116,964 patches  |  mining so far: 845
#    58.1%  |  68,000/116,964 patches  |  mining so far: 855
#    59.0%  |  69,000/116,964 patches  |  mining so far: 880
#    59.8%  |  70,000/116,964 patches  |  mining so far: 907
#    60.7%  |  71,000/116,964 patches  |  mining so far: 956
#    61.6%  |  72,000/116,964 patches  |  mining so far: 1,012
#    62.4%  |  73,000/116,964 patches  |  mining so far: 1,060
#    63.3%  |  74,000/116,964 patches  |  mining so far: 1,139
#    64.1%  |  75,000/116,964 patches  |  mining so far: 1,226
#    65.0%  |  76,000/116,964 patches  |  mining so far: 1,302
#    65.8%  |  77,000/116,964 patches  |  mining so far: 1,384
#    66.7%  |  78,000/116,964 patches  |  mining so far: 1,469
#    67.5%  |  79,000/116,964 patches  |  mining so far: 1,567
#    68.4%  |  80,000/116,964 patches  |  mining so far: 1,666
#    69.3%  |  81,000/116,964 patches  |  mining so far: 1,771
#    70.1%  |  82,000/116,964 patches  |  mining so far: 1,814
#    71.0%  |  83,000/116,964 patches  |  mining so far: 1,852
#    71.8%  |  84,000/116,964 patches  |  mining so far: 1,906
#    72.7%  |  85,000/116,964 patches  |  mining so far: 1,999
#    73.5%  |  86,000/116,964 patches  |  mining so far: 2,079
#    74.4%  |  87,000/116,964 patches  |  mining so far: 2,155
#    75.2%  |  88,000/116,964 patches  |  mining so far: 2,233
#    76.1%  |  89,000/116,964 patches  |  mining so far: 2,256
#    76.9%  |  90,000/116,964 patches  |  mining so far: 2,282
#    77.8%  |  91,000/116,964 patches  |  mining so far: 2,306
#    78.7%  |  92,000/116,964 patches  |  mining so far: 2,335
#    79.5%  |  93,000/116,964 patches  |  mining so far: 2,346
#    80.4%  |  94,000/116,964 patches  |  mining so far: 2,356
#    81.2%  |  95,000/116,964 patches  |  mining so far: 2,378
#    82.1%  |  96,000/116,964 patches  |  mining so far: 2,397
#    82.9%  |  97,000/116,964 patches  |  mining so far: 2,404
#    83.8%  |  98,000/116,964 patches  |  mining so far: 2,416
#    84.6%  |  99,000/116,964 patches  |  mining so far: 2,436
#    85.5%  |  100,000/116,964 patches  |  mining so far: 2,472
#    86.4%  |  101,000/116,964 patches  |  mining so far: 2,494
#    87.2%  |  102,000/116,964 patches  |  mining so far: 2,521
#    88.1%  |  103,000/116,964 patches  |  mining so far: 2,539
#    88.9%  |  104,000/116,964 patches  |  mining so far: 2,554
#    89.8%  |  105,000/116,964 patches  |  mining so far: 2,562
#    90.6%  |  106,000/116,964 patches  |  mining so far: 2,566
#    91.5%  |  107,000/116,964 patches  |  mining so far: 2,573
#    92.3%  |  108,000/116,964 patches  |  mining so far: 2,593
#    93.2%  |  109,000/116,964 patches  |  mining so far: 2,614
#    94.0%  |  110,000/116,964 patches  |  mining so far: 2,627
#    94.9%  |  111,000/116,964 patches  |  mining so far: 2,657
#    95.8%  |  112,000/116,964 patches  |  mining so far: 2,684
#    96.6%  |  113,000/116,964 patches  |  mining so far: 2,709
#    97.5%  |  114,000/116,964 patches  |  mining so far: 2,736
#    98.3%  |  115,000/116,964 patches  |  mining so far: 2,772
#    99.2%  |  116,000/116,964 patches  |  mining so far: 2,793
#   100.0%  |  116,964/116,964 patches  |  mining so far: 2,806
#   Result: 2,806 mining patches  |  167.22 km2  |  1.39% coverage
#
#   Best scene for 2025: 20250516 (172.34 km2)
#   Saved overlay: inference_output/temporal\2025_overlay.png
#   Saved heatmap : inference_output/temporal\2025_heatmap.png
#
# ============================================================
#   BATCH INFERENCE COMPLETE
#   Years processed: 5
#   Total JP2 files: 29
# ============================================================
# All scenes saved: inference_output/temporal\all_scenes_results.csv
#  year     date  n_mining  area_km2  coverage_pct
#  2021 20210226      3595  191.8976      1.591713
#  2021 20210328      3081  153.1904      1.270653
#  2021 20210427      3151  176.7424      1.466007
#  2021 20211024      1595  123.0848      1.020939
#  2021 20211123      1694  124.7232      1.034529
#  2021 20211223      2327  155.9552      1.293586
#  2022 20220102      2282  153.6000      1.274050
#  2022 20220412      2358  142.1312      1.178921
#  2022 20220611      2494  161.7920      1.342000
#  2022 20220830      1782  121.1392      1.004801
#  2022 20221029      2007  156.2624      1.296134
#  2022 20221128      2771  189.0304      1.567931
#  2023 20230107      4217  246.0672      2.041028
#  2023 20230226      3735  193.1264      1.601906
#  2023 20230328      3096  160.1536      1.328410
#  2023 20230527      2653  170.7008      1.415894
#  2023 20231014      1571  113.8688      0.944496
#  2023 20231123      2053  135.4752      1.123712
#  2024 20240112      3024  190.0544      1.576425
#  2024 20240211      2293  157.6960      1.308025
#  2024 20240401      2274  158.3104      1.313121
#  2024 20240610      2579  169.8816      1.409100
#  2024 20241117      2206  167.8336      1.392112
#  2024 20241207      2197  150.7328      1.250268
#  2025 20250106      3005  191.5904      1.589165
#  2025 20250329      2541  161.1776      1.336903
#  2025 20250516      2520  172.3392      1.429484
#  2025 20251114      2788  198.9632      1.650320
#  2025 20251224      2806  167.2192      1.387016
#
# Yearly summary saved: inference_output/temporal\yearly_summary.csv
#
# =======================================================
#   YEAR-WISE SUMMARY
# =======================================================
# Year   Date       Patches    Area km2     Change
# -------------------------------------------------------
# 2021   20211223   2327       155.96       baseline
# 2022   20221029   2007       156.26       +0.31 km2 (+0.2%)
# 2023   20230527   2653       170.70       +14.44 km2 (+9.2%)
# 2024   20241117   2206       167.83       -2.87 km2 (-1.7%)
# 2025   20250516   2520       172.34       +4.51 km2 (+2.7%)
# =======================================================
#
# All outputs saved to: inference_output/temporal/
# Now run temporal_analysis.ipynb to generate charts.
# Saved: inference_output/temporal\all_years_overview.png

# %% [markdown]
# ## Cell 6 — Save Combined CSV
#
# Saves all results to a single CSV that `temporal_analysis.ipynb` will read.

# %% [markdown]
# ## Cell 7 — Quick Preview: All Overlay Maps Side by Side
